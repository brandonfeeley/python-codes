# %%
#Imports

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch

# %% [markdown]
# # USE FILTER BELOW

# %%
df = pd.read_csv(r'C:\Users\Feele\Documents\Data\Sunderland\shotfilter.csv')

# %%
df
# Out:
#    Unnamed: 0  Unnamed: 0.1          id  eventId  minute  second  teamId  \
# 0         834           840  2293097841      455      46    20.0    1974
# 1        1212          1218  2293113819      661      68    47.0    1974
# 2        1300          1306  2293117719      710      74    35.0    1974
# 3        1351          1357  2293119435      745      78     6.0    1974
# 4        1443          1449  2293121097      799      82    45.0    1974
# 5        1448          1454  2293121233      802      83    11.0    1974
# 6        1452          1458  2293127051      895      83    16.0    1974
# 7        1454          1460  2293121307      803      83    19.0    1974
#
#       x     y  expandedMinute  ...  qualifiers/11/value isGoal  \
# 0  80.6  60.0              50  ...                  NaN    NaN
# 1  91.9  41.2              72  ...                  NaN    NaN
# 2  91.3  49.7              78  ...                745.0    NaN
# 3  78.5  59.4              82  ...                  NaN    NaN
# 4  95.7  39.8              86  ...                 45.8    NaN
# 5  85.7  55.3              87  ...                  NaN    NaN
# 6  83.8  66.6              87  ...                  NaN    NaN
# 7  84.6  52.2              87  ...                  NaN   True
#
#    cardType/value cardType/displayName  qualifiers/13/value  \
# 0             NaN                  NaN                  NaN
# 1             NaN                  NaN                 15.8
# 2             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 4             NaN                  NaN                 46.1
# 5             NaN                  NaN                 19.0
# 6             NaN                  NaN                  NaN
# 7             NaN                  NaN                  NaN
#
#   qualifiers/14/value  qualifiers/15/type/value  \
# 0                 NaN                       NaN
# 1              Center                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN
# 5                 NaN                       NaN
# 6                 NaN                       NaN
# 7                 NaN                       NaN
#
#    qualifiers/15/type/displayName  qualifiers/15/value number
# 0                             NaN                  NaN    8.0
# 1                             NaN                  NaN   22.0
# 2                             NaN                  NaN   27.0
# 3                             NaN                  NaN    8.0
# 4                             NaN                  NaN    7.0
# 5                             NaN                  NaN   26.0
# 6                             NaN                  NaN   22.0
# 7                             NaN                  NaN   26.0
#
# [8 rows x 95 columns]

# %%
# Inflating X and Y to pitch size

df['x'] = df['x']*1.2
df['y'] = df['y']*.8

# %% [markdown]
# #### Light Pitch
#
# Background - #FFFFFF
# lines - #B4B6BA
#
# #### Dark Pitch
#
# Background - #1B1B1B
# lines - #c7d5cc
#
# #### Blue Pitch (Primary colour)
# Background - #0B0725
# lines - #B4B6BA

# %%
fig,ax = plt.subplots(figsize=(13,8.5))
fig.set_facecolor('#0B0725')
ax.patch.set_facecolor('#0B0725')

# Setup the pitch
pitch = Pitch(pitch_type='statsbomb', orientation='horizontal', half=True, 
              pitch_color='#0B0725', line_color='#B4B6BA', figsize=(13, 8),
              constrained_layout=True, tight_layout=False)


pitch.draw(ax=ax)
plt.gca().invert_yaxis()


for x in range(len(df['x'])):
      if df['type/displayName'][x] == 'Goal':
        plt.scatter(df['x'][x],df['y'][x], c='#00B050',s=200)
        
      if df['type/displayName'][x] == 'MissedShots':
        plt.scatter(df['x'][x],df['y'][x], c='#D70232',s=200)
        
      if df['type/displayName'][x] == 'SavedShot':
        plt.scatter(df['x'][x],df['y'][x], c='#1A78CF',s=200)
        
      if df['type/displayName'][x] == 'ShotOnPost':
        plt.scatter(df['x'][x],df['y'][x], c='#FF9300',s=200)
        
plt.savefig('test.png',dpi=500,bbox_inches = 'tight')

# %%
pitch = Pitch(positional=True, shade_middle=True, positional_color='#eadddd', shade_color='#f2f2f2')
fig, ax = pitch.draw()

# %%
fig,ax = plt.subplots(figsize=(13,8))
fig.set_facecolor('#0B0725')
ax.patch.set_facecolor('#0B0725')

# Setup the pitch
pitch = Pitch(pitch_type='statsbomb', orientation='horizontal', positional=True, 
              shade_middle=True, positional_color='#eadddd', shade_color='#100369',
              pitch_color='#0B0725', line_color='#B4B6BA', figsize=(13, 8),
              constrained_layout=True, tight_layout=False)


pitch.draw(ax=ax)
plt.gca().invert_yaxis()
