# %%
#Imports

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mplsoccer.pitch import Pitch

# %% [markdown]
# # USE FILTER BELOW

# %%
df = pd.read_csv(r'C:\Users\Feele\Documents\Sunderland\Data\shotfilter.csv')

# %%
df
# Out:
#     Unnamed: 0          id  eventId  minute  second  teamId     x     y  endX  \
# 0          154  2277944047       88       9     9.0      16  75.9  33.3   NaN
# 1          164  2277945189       97       9    42.0      16  71.4  65.1   NaN
# 2          304  2277964943      178      19    30.0      16  78.8  31.3   NaN
# 3          311  2277965543      185      19    49.0      16  88.9  73.2   NaN
# 4          590  2277998375      355      37    38.0      16  87.2  62.0   NaN
# 5          614  2278000939      374      38    51.0      16  74.2  50.7   NaN
# 6          636  2278003273      389      39    55.0      16  94.0  54.6   NaN
# 7          802  2278039587      489      49    53.0      16  90.9  39.4   NaN
# 8          903  2278062963      549      61    28.0      16  79.3  28.0   NaN
# 9         1060  2278081359      623      71    39.0      16  88.1  57.8   NaN
# 10        1145  2278091055      658      77     8.0      16  75.9  42.7   NaN
# 11        1193  2278096715      691      80    14.0      16  86.5  57.5   NaN
# 12        1412  2278119231      799      92    47.0      16  75.9  37.6   NaN
#
#     endY  period/value  type/value type/displayName  outcomeType/value  \
# 0    NaN             1          13      MissedShots                  1
# 1    NaN             1          15        SavedShot                  1
# 2    NaN             1          15        SavedShot                  1
# 3    NaN             1          15        SavedShot                  1
# 4    NaN             1          13      MissedShots                  1
# 5    NaN             1          15        SavedShot                  1
# 6    NaN             1          16             Goal                  1
# 7    NaN             2          15        SavedShot                  1
# 8    NaN             2          15        SavedShot                  1
# 9    NaN             2          15        SavedShot                  1
# 10   NaN             2          15        SavedShot                  1
# 11   NaN             2          13      MissedShots                  1
# 12   NaN             2          15        SavedShot                  1
#
#    outcomeType/displayName  playerId  player_num        name
# 0               Successful  134442.0         6.0       Power
# 1               Successful   12417.0        23.0  Leadbitter
# 2               Successful  294849.0        11.0       Gooch
# 3               Successful  134185.0        25.0   McFadzean
# 4               Successful    9003.0        28.0     McGeady
# 5               Successful  134442.0         6.0       Power
# 6               Successful  134185.0        25.0   McFadzean
# 7               Successful  134636.0         2.0  McLaughlin
# 8               Successful    9003.0        28.0     McGeady
# 9               Successful  397143.0        31.0     Stewart
# 10              Successful   13860.0         7.0     Maguire
# 11              Successful  111787.0         9.0        Wyke
# 12              Successful    9003.0        28.0     McGeady

# %%
# Inflating X and Y to pitch size

df['x'] = df['x']*1.2
df['y'] = df['y']*.8

# %% [markdown]
# #### Light Pitch
#
# Background - #FFFFFF
# lines - #B4B6BA
#
# #### Dark Pitch
#
# Background - #1B1B1B
# lines - #c7d5cc
#
# #### Blue Pitch (Primary colour)
# Background - #0B0725
# lines - #B4B6BA

# %%
fig,ax = plt.subplots(figsize=(13,8.5))
fig.set_facecolor('#0B0725')
ax.patch.set_facecolor('#0B0725')

# Setup the pitch
pitch = Pitch(pitch_type='statsbomb', orientation='horizontal', half=True, 
              pitch_color='#0B0725', line_color='#B4B6BA', figsize=(13, 8),
              constrained_layout=True, tight_layout=False)


pitch.draw(ax=ax)
plt.gca().invert_yaxis()


for x in range(len(df['x'])):
      if df['type/displayName'][x] == 'Goal':
        plt.scatter(df['x'][x],df['y'][x], c='#00B050',s=200)
        
      if df['type/displayName'][x] == 'MissedShots':
        plt.scatter(df['x'][x],df['y'][x], c='#D70232',s=200)
        
      if df['type/displayName'][x] == 'SavedShot':
        plt.scatter(df['x'][x],df['y'][x], c='#1A78CF',s=200)
        
      if df['type/displayName'][x] == 'ShotOnPost':
        plt.scatter(df['x'][x],df['y'][x], c='#FF9300',s=200)
        
plt.savefig('test.png',dpi=500,bbox_inches = 'tight')

# %%
pitch = Pitch(positional=True, shade_middle=True, positional_color='#eadddd', shade_color='#f2f2f2')
fig, ax = pitch.draw()

# %%
fig,ax = plt.subplots(figsize=(13,8))
fig.set_facecolor('#0B0725')
ax.patch.set_facecolor('#0B0725')

# Setup the pitch
pitch = Pitch(pitch_type='statsbomb', orientation='horizontal', positional=True, 
              shade_middle=True, positional_color='#eadddd', shade_color='#100369',
              pitch_color='#0B0725', line_color='#B4B6BA', figsize=(13, 8),
              constrained_layout=True, tight_layout=False)


pitch.draw(ax=ax)
plt.gca().invert_yaxis()
